# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, InputLayer
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanAbsoluteError
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import mean_absolute_error
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Flatten

# %%
data_path = 'date_data.csv'
df = pd.read_csv(data_path)

# %%
print(df.columns)
# Out:
# Index(['dt', 'Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3', 'power_consumption'],
#       dtype='object')

# %%
df['dt'] = pd.to_datetime(df['dt'], format="%Y-%m-%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dt                     1426 non-null   datetime64[ns]
#  1   Global_active_power    1426 non-null   float64
#  2   Global_reactive_power  1426 non-null   float64
#  3   Voltage                1426 non-null   float64
#  4   Global_intensity       1426 non-null   float64
#  5   Sub_metering_1         1426 non-null   float64
#  6   Sub_metering_2         1426 non-null   float64
#  7   Sub_metering_3         1426 non-null   float64
#  8   power_consumption      1426 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 100.4 KB

# %%
df.describe()
# Out:
#                         dt  Global_active_power  Global_reactive_power  \
# count                 1426          1426.000000            1426.000000
# mean   2008-12-13 12:00:00             1.077442               0.123239
# min    2007-01-01 00:00:00             0.146000               0.000000
# 25%    2007-12-23 06:00:00             0.807992               0.098345
# 50%    2008-12-13 12:00:00             1.065741               0.118883
# 75%    2009-12-04 18:00:00             1.309216               0.141284
# max    2010-11-26 00:00:00             2.798418               0.290162
# std                    NaN             0.408821               0.035139
#
#            Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# count  1426.000000       1426.000000     1426.000000     1426.000000
# mean    240.835142          4.567550        1.109464        1.277929
# min     231.088229          0.600000        0.000000        0.000000
# 25%     240.065377          3.484028        0.402604        0.298611
# 50%     240.962701          4.520000        0.771181        0.472569
# 75%     241.881823          5.517917        1.527778        1.883681
# max     247.435007         11.815972        7.794444        8.409028
# std       2.049902          1.690637        1.103123        1.444686
#
#        Sub_metering_3  power_consumption
# count     1426.000000        1426.000000
# mean         6.406059           9.163919
# min          0.000000           1.433333
# 25%          4.595486           6.443287
# 50%          6.427431           8.675787
# 75%          8.135764          11.413744
# max         19.000000          27.972639
# std          2.647284           3.988913

# %%
print(len(df))
df.head()
# Out:
# 1426
#           dt  Global_active_power  Global_reactive_power     Voltage  \
# 0 2007-01-01             1.909031               0.102893  240.128979
# 1 2007-01-02             0.881414               0.132182  241.943778
# 2 2007-01-03             0.704204               0.136617  243.557090
# 3 2007-01-04             2.263481               0.140487  239.750299
# 4 2007-01-05             1.884281               0.120246  240.495764
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0          7.916944        0.000000        0.244444        4.083333
# 1          3.714028        0.000000        0.241667        4.556944
# 2          3.014028        0.000000        0.238889        3.309028
# 3          9.478194        0.729861        5.275694        7.566667
# 4          7.885139        1.029861        0.263194        5.279167
#
#    power_consumption
# 0          27.489398
# 1           9.891620
# 2           8.188819
# 3          24.152454
# 4          24.832454

# %%
n = len(df)
train = df[:int(n*0.7)]
val = df[int(n*0.7):int(n*0.85)]
test = df[int(n*0.85):]

# %%
X_train, y_train = train.drop('Global_active_power', axis=1), train['Global_active_power']
X_val, y_val = val.drop('Global_active_power', axis=1), val['Global_active_power']
X_test, y_test = test.drop('Global_active_power', axis=1), test['Global_active_power']

# Drop the 'dt' column
X_train = X_train.drop('dt', axis=1)
X_val = X_val.drop('dt', axis=1)
X_test = X_test.drop('dt', axis=1)

# Reshape the data to fit LSTM input shape
num_features = X_train.shape[1]
X_train = X_train.values.reshape((X_train.shape[0], 1, num_features))
X_val = X_val.values.reshape((X_val.shape[0], 1, num_features))
X_test = X_test.values.reshape((X_test.shape[0], 1, num_features))

# %%
cnn_model = Sequential()

# Thêm lớp đầu vào
cnn_model.add(InputLayer((1, num_features)))

# Thêm lớp Conv1D
cnn_model.add(Conv1D(64, kernel_size=1, activation='relu'))

# Thêm lớp Flatten để chuyển đổi tensor 3D thành tensor 2D
cnn_model.add(Flatten())

# Thêm lớp Dense cuối cùng
cnn_model.add(Dense(1))

# Biên dịch mô hình
cnn_model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[MeanAbsoluteError()])

# Huấn luyện mô hình, sử dụng tập validation
cnn_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 33.0832 - mean_absolute_error: 5.5323 - val_loss: 0.8877 - val_mean_absolute_error: 0.8320
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8095 - mean_absolute_error: 0.7330 - val_loss: 0.6357 - val_mean_absolute_error: 0.6879
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3975 - mean_absolute_error: 0.4990 - val_loss: 0.2852 - val_mean_absolute_error: 0.4282
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3603 - mean_absolute_error: 0.4685 - val_loss: 0.2909 - val_mean_absolute_error: 0.4389
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3550 - mean_absolute_error: 0.4683 - val_loss: 0.2565 - val_mean_absolute_error: 0.4136
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2712 - mean_absolute_error: 0.4055 - val_loss: 0.2020 - val_mean_absolute_error: 0.3604
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2546 - mean_absolute_error: 0.3890 - val_loss: 0.1762 - val_mean_absolute_error: 0.3348
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1954 - mean_absolute_error: 0.3365 - val_loss: 0.1606 - val_mean_absolute_error: 0.3193
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1818 - mean_absolute_error: 0.3250 - val_loss: 0.1329 - val_mean_absolute_error: 0.2877
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1547 - mean_absolute_error: 0.2981 - val_loss: 0.1376 - val_mean_absolute_error: 0.2964
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1314 - mean_absolute_error: 0.2807 - val_loss: 0.1038 - val_mean_absolute_error: 0.2530
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1241 - mean_absolute_error: 0.2690 - val_loss: 0.1067 - val_mean_absolute_error: 0.2590
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1068 - mean_absolute_error: 0.2519 - val_loss: 0.0961 - val_mean_absolute_error: 0.2457
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0927 - mean_absolute_error: 0.2370 - val_loss: 0.0780 - val_mean_absolute_error: 0.2192
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0771 - mean_absolute_error: 0.2155 - val_loss: 0.0723 - val_mean_absolute_error: 0.2112
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0697 - mean_absolute_error: 0.2078 - val_loss: 0.0659 - val_mean_absolute_error: 0.2019
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643 - mean_absolute_error: 0.1968 - val_loss: 0.0620 - val_mean_absolute_error: 0.1967
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0572 - mean_absolute_error: 0.1882 - val_loss: 0.0598 - val_mean_absolute_error: 0.1947
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0415 - mean_absolute_error: 0.1585 - val_loss: 0.0549 - val_mean_absolute_error: 0.1869
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0375 - mean_absolute_error: 0.1543 - val_loss: 0.0412 - val_mean_absolute_error: 0.1595
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0321 - mean_absolute_error: 0.1407 - val_loss: 0.0427 - val_mean_absolute_error: 0.1646
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - mean_absolute_error: 0.1277 - val_loss: 0.0335 - val_mean_absolute_error: 0.1440
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - mean_absolute_error: 0.1163 - val_loss: 0.0369 - val_mean_absolute_error: 0.1543
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - mean_absolute_error: 0.1140 - val_loss: 0.0328 - val_mean_absolute_error: 0.1455
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0174 - mean_absolute_error: 0.1030 - val_loss: 0.0280 - val_mean_absolute_error: 0.1335
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - mean_absolute_error: 0.0955 - val_loss: 0.0263 - val_mean_absolute_error: 0.1301
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0912 - val_loss: 0.0231 - val_mean_absolute_error: 0.1216
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0859 - val_loss: 0.0213 - val_mean_absolute_error: 0.1169
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - mean_absolute_error: 0.0816 - val_loss: 0.0188 - val_mean_absolute_error: 0.1096
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0776 - val_loss: 0.0175 - val_mean_absolute_error: 0.1056
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0698 - val_loss: 0.0153 - val_mean_absolute_error: 0.0987
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mean_absolute_error: 0.0657 - val_loss: 0.0153 - val_mean_absolute_error: 0.0993
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mean_absolute_error: 0.0646 - val_loss: 0.0125 - val_mean_absolute_error: 0.0890
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0597 - val_loss: 0.0127 - val_mean_absolute_error: 0.0901
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0578 - val_loss: 0.0105 - val_mean_absolute_error: 0.0810
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0537 - val_loss: 0.0116 - val_mean_absolute_error: 0.0865
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0523 - val_loss: 0.0085 - val_mean_absolute_error: 0.0728
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0498 - val_loss: 0.0081 - val_mean_absolute_error: 0.0709
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0486 - val_loss: 0.0075 - val_mean_absolute_error: 0.0681
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0458 - val_loss: 0.0096 - val_mean_absolute_error: 0.0796
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0459 - val_loss: 0.0072 - val_mean_absolute_error: 0.0676
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0447 - val_loss: 0.0067 - val_mean_absolute_error: 0.0649
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0444 - val_loss: 0.0063 - val_mean_absolute_error: 0.0633
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0416 - val_loss: 0.0060 - val_mean_absolute_error: 0.0620
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0407 - val_loss: 0.0046 - val_mean_absolute_error: 0.0534
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0395 - val_loss: 0.0049 - val_mean_absolute_error: 0.0555
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0371 - val_loss: 0.0051 - val_mean_absolute_error: 0.0574
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0364 - val_loss: 0.0041 - val_mean_absolute_error: 0.0508
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0362 - val_loss: 0.0039 - val_mean_absolute_error: 0.0493
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0340 - val_loss: 0.0041 - val_mean_absolute_error: 0.0510

# %%
cnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 1, 64)          │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,733 (6.77 KB)
#  Trainable params: 577 (2.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,156 (4.52 KB)

# %%
# Huấn luyện mô hình, sử dụng tập validation
history = cnn_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# Lấy dữ liệu loss từ lịch sử huấn luyện
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Tạo một chuỗi epochs để vẽ trên trục x
epochs = range(len(training_loss))

# Vẽ biểu đồ
plt.figure(figsize=(12, 8))

plt.plot(epochs, training_loss, label='Training Loss', color='blue')
plt.plot(epochs, validation_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0330 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0320 - val_loss: 0.0033 - val_mean_absolute_error: 0.0455
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0300 - val_loss: 0.0029 - val_mean_absolute_error: 0.0425
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0299 - val_loss: 0.0026 - val_mean_absolute_error: 0.0401
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0284 - val_loss: 0.0022 - val_mean_absolute_error: 0.0365
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0284 - val_loss: 0.0022 - val_mean_absolute_error: 0.0367
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0259 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0265 - val_loss: 0.0020 - val_mean_absolute_error: 0.0360
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4566e-04 - mean_absolute_error: 0.0241 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7637e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8148e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1359e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5217e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1311e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1975e-04 - mean_absolute_error: 0.0196 - val_loss: 9.6339e-04 - val_mean_absolute_error: 0.0245
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7676e-04 - mean_absolute_error: 0.0190 - val_loss: 8.5537e-04 - val_mean_absolute_error: 0.0231
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2432e-04 - mean_absolute_error: 0.0181 - val_loss: 9.8896e-04 - val_mean_absolute_error: 0.0254
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4120e-04 - mean_absolute_error: 0.0185 - val_loss: 6.1599e-04 - val_mean_absolute_error: 0.0197
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7562e-04 - mean_absolute_error: 0.0175 - val_loss: 5.5349e-04 - val_mean_absolute_error: 0.0187
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0175e-04 - mean_absolute_error: 0.0160 - val_loss: 6.4663e-04 - val_mean_absolute_error: 0.0203
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9195e-04 - mean_absolute_error: 0.0157 - val_loss: 4.2539e-04 - val_mean_absolute_error: 0.0164
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9956e-04 - mean_absolute_error: 0.0158 - val_loss: 5.3570e-04 - val_mean_absolute_error: 0.0186
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2826e-04 - mean_absolute_error: 0.0143 - val_loss: 4.0568e-04 - val_mean_absolute_error: 0.0160
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2873e-04 - mean_absolute_error: 0.0144 - val_loss: 3.5046e-04 - val_mean_absolute_error: 0.0149
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8264e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8883e-04 - val_mean_absolute_error: 0.0135
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8430e-04 - mean_absolute_error: 0.0135 - val_loss: 3.0112e-04 - val_mean_absolute_error: 0.0138
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4294e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5518e-04 - val_mean_absolute_error: 0.0127
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1631e-04 - mean_absolute_error: 0.0116 - val_loss: 2.1739e-04 - val_mean_absolute_error: 0.0117
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2179e-04 - mean_absolute_error: 0.0117 - val_loss: 1.8769e-04 - val_mean_absolute_error: 0.0108
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9895e-04 - mean_absolute_error: 0.0111 - val_loss: 1.7382e-04 - val_mean_absolute_error: 0.0104
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9586e-04 - mean_absolute_error: 0.0110 - val_loss: 1.5513e-04 - val_mean_absolute_error: 0.0097
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9021e-04 - mean_absolute_error: 0.0109 - val_loss: 1.4064e-04 - val_mean_absolute_error: 0.0092
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7269e-04 - mean_absolute_error: 0.0106 - val_loss: 1.3590e-04 - val_mean_absolute_error: 0.0092
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5156e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2055e-04 - val_mean_absolute_error: 0.0084
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4158e-04 - mean_absolute_error: 0.0094 - val_loss: 1.1375e-04 - val_mean_absolute_error: 0.0083
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3300e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0373e-04 - val_mean_absolute_error: 0.0078
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2323e-04 - mean_absolute_error: 0.0088 - val_loss: 9.7786e-05 - val_mean_absolute_error: 0.0076
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1787e-04 - mean_absolute_error: 0.0084 - val_loss: 9.0247e-05 - val_mean_absolute_error: 0.0073
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2137e-04 - mean_absolute_error: 0.0088 - val_loss: 9.6467e-05 - val_mean_absolute_error: 0.0078
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2421e-04 - mean_absolute_error: 0.0089 - val_loss: 8.3917e-05 - val_mean_absolute_error: 0.0071
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1352e-04 - mean_absolute_error: 0.0086 - val_loss: 7.9666e-05 - val_mean_absolute_error: 0.0068
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1111e-04 - mean_absolute_error: 0.0083 - val_loss: 8.9525e-05 - val_mean_absolute_error: 0.0073
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9099e-05 - mean_absolute_error: 0.0079 - val_loss: 7.9724e-05 - val_mean_absolute_error: 0.0069
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6764e-05 - mean_absolute_error: 0.0078 - val_loss: 7.0134e-05 - val_mean_absolute_error: 0.0064
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4347e-05 - mean_absolute_error: 0.0077 - val_loss: 7.3851e-05 - val_mean_absolute_error: 0.0066
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9548e-05 - mean_absolute_error: 0.0078 - val_loss: 6.6543e-05 - val_mean_absolute_error: 0.0062
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0457e-04 - mean_absolute_error: 0.0081 - val_loss: 7.1390e-05 - val_mean_absolute_error: 0.0065
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3810e-05 - mean_absolute_error: 0.0077 - val_loss: 7.2500e-05 - val_mean_absolute_error: 0.0065
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8212e-05 - mean_absolute_error: 0.0074 - val_loss: 7.8966e-05 - val_mean_absolute_error: 0.0069
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7007e-05 - mean_absolute_error: 0.0074 - val_loss: 8.5870e-05 - val_mean_absolute_error: 0.0073

# %%
# Đánh giá mô hình trên tập kiểm tra
test_loss, test_mae = cnn_model.evaluate(X_test, y_test, verbose=0)

print(f"Độ lỗi trên tập kiểm tra: {test_loss}")
print(f"Độ chính xác trên tập kiểm tra: {test_mae}")

# Dự đoán giá trị trên tập kiểm tra
predictions = cnn_model.predict(X_test)

# Tính toán Mean Absolute Error
mae = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
# Out:
# Độ lỗi trên tập kiểm tra: 0.002413274021819234
# Độ chính xác trên tập kiểm tra: 0.038390371948480606
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Mean Absolute Error: 0.03839036728147225

# %%
import matplotlib.pyplot as plt

# Dự đoán giá trị trên tập huấn luyện và kiểm tra
cnn_train_pred = cnn_model.predict(X_train).flatten()
cnn_test_pred = cnn_model.predict(X_test).flatten()

plt.figure(figsize=(24,8))

# Vẽ giá trị thực tế
plt.plot(np.concatenate([y_train, y_test]), label='Giá thực tế', color='red')

# Vẽ kết quả dự đoán từ mô hình CNN trên tập huấn luyện
plt.plot(range(len(y_train)), cnn_train_pred, label='Giá dự đoán train', color='green')

# Vẽ kết quả dự đoán từ mô hình CNN trên tập kiểm tra
plt.plot(range(len(y_train), len(y_train) + len(y_test)), cnn_test_pred, label='Giá dự đoán test', color='blue')

plt.title('So sánh dự báo và thực tế sử dụng mô hình CNN') # Đặt tên biểu đồ
plt.xlabel('Thời gian') # Đặt tên hàm x
plt.ylabel('Sản lượng điện') # Đặt tên hàm y
plt.legend() # Chú thích
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from tensorflow.keras.layers import LSTM

# Khởi tạo mô hình
modelCNNLSTM = Sequential()

# Thêm lớp đầu vào
modelCNNLSTM.add(InputLayer((1, num_features)))

# Thêm lớp Conv1D
modelCNNLSTM.add(Conv1D(64, kernel_size=1, activation='relu'))

# Thêm lớp LSTM
modelCNNLSTM.add(LSTM(32))

# Thêm lớp Dense cuối cùng
modelCNNLSTM.add(Dense(1))

# Biên dịch mô hình
modelCNNLSTM.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[MeanAbsoluteError()])

# Huấn luyện mô hình, sử dụng tập validation
modelCNNLSTM.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.8259 - mean_absolute_error: 1.2556 - val_loss: 1.0745 - val_mean_absolute_error: 0.9917
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7053 - mean_absolute_error: 0.7333 - val_loss: 0.2720 - val_mean_absolute_error: 0.4338
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2388 - mean_absolute_error: 0.3723 - val_loss: 0.1338 - val_mean_absolute_error: 0.2845
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1382 - mean_absolute_error: 0.2743 - val_loss: 0.1350 - val_mean_absolute_error: 0.2931
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1308 - mean_absolute_error: 0.2564 - val_loss: 0.1197 - val_mean_absolute_error: 0.2655
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1395 - mean_absolute_error: 0.2623 - val_loss: 0.1169 - val_mean_absolute_error: 0.2618
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1264 - mean_absolute_error: 0.2496 - val_loss: 0.1080 - val_mean_absolute_error: 0.2484
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1317 - mean_absolute_error: 0.2529 - val_loss: 0.1018 - val_mean_absolute_error: 0.2394
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1282 - mean_absolute_error: 0.2400 - val_loss: 0.0942 - val_mean_absolute_error: 0.2302
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0847 - mean_absolute_error: 0.1939 - val_loss: 0.0500 - val_mean_absolute_error: 0.1641
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0695 - mean_absolute_error: 0.1784 - val_loss: 0.0327 - val_mean_absolute_error: 0.1264
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583 - mean_absolute_error: 0.1633 - val_loss: 0.0349 - val_mean_absolute_error: 0.1311
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mean_absolute_error: 0.1478 - val_loss: 0.0400 - val_mean_absolute_error: 0.1469
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.1371 - val_loss: 0.0377 - val_mean_absolute_error: 0.1406
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0397 - mean_absolute_error: 0.1296 - val_loss: 0.0301 - val_mean_absolute_error: 0.1219
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0343 - mean_absolute_error: 0.1232 - val_loss: 0.0292 - val_mean_absolute_error: 0.1196
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0324 - mean_absolute_error: 0.1194 - val_loss: 0.0285 - val_mean_absolute_error: 0.1221
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0318 - mean_absolute_error: 0.1153 - val_loss: 0.0237 - val_mean_absolute_error: 0.1068
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0291 - mean_absolute_error: 0.1071 - val_loss: 0.0255 - val_mean_absolute_error: 0.1077
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0229 - mean_absolute_error: 0.0997 - val_loss: 0.0222 - val_mean_absolute_error: 0.1010
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0287 - mean_absolute_error: 0.1049 - val_loss: 0.0198 - val_mean_absolute_error: 0.0932
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0284 - mean_absolute_error: 0.1036 - val_loss: 0.0197 - val_mean_absolute_error: 0.0947
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - mean_absolute_error: 0.0907 - val_loss: 0.0189 - val_mean_absolute_error: 0.0953
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0223 - mean_absolute_error: 0.0929 - val_loss: 0.0155 - val_mean_absolute_error: 0.0823
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0855 - val_loss: 0.0137 - val_mean_absolute_error: 0.0760
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0196 - mean_absolute_error: 0.0857 - val_loss: 0.0160 - val_mean_absolute_error: 0.0901
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mean_absolute_error: 0.0799 - val_loss: 0.0116 - val_mean_absolute_error: 0.0700
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0762 - val_loss: 0.0137 - val_mean_absolute_error: 0.0827
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170 - mean_absolute_error: 0.0758 - val_loss: 0.0096 - val_mean_absolute_error: 0.0635
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0171 - mean_absolute_error: 0.0772 - val_loss: 0.0133 - val_mean_absolute_error: 0.0864
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mean_absolute_error: 0.0786 - val_loss: 0.0089 - val_mean_absolute_error: 0.0624
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0664 - val_loss: 0.0099 - val_mean_absolute_error: 0.0709
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145 - mean_absolute_error: 0.0700 - val_loss: 0.0056 - val_mean_absolute_error: 0.0524
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - mean_absolute_error: 0.0623 - val_loss: 0.0065 - val_mean_absolute_error: 0.0614
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mean_absolute_error: 0.0551 - val_loss: 0.0060 - val_mean_absolute_error: 0.0600
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0479 - val_loss: 0.0043 - val_mean_absolute_error: 0.0473
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - mean_absolute_error: 0.0538 - val_loss: 0.0040 - val_mean_absolute_error: 0.0462
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mean_absolute_error: 0.0476 - val_loss: 0.0046 - val_mean_absolute_error: 0.0526
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0439 - val_loss: 0.0054 - val_mean_absolute_error: 0.0587
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - mean_absolute_error: 0.0477 - val_loss: 0.0050 - val_mean_absolute_error: 0.0575
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0455 - val_loss: 0.0037 - val_mean_absolute_error: 0.0477
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0429 - val_loss: 0.0036 - val_mean_absolute_error: 0.0458
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0385 - val_loss: 0.0046 - val_mean_absolute_error: 0.0560
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0413 - val_loss: 0.0032 - val_mean_absolute_error: 0.0426
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - mean_absolute_error: 0.0419 - val_loss: 0.0023 - val_mean_absolute_error: 0.0364
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0366 - val_loss: 0.0040 - val_mean_absolute_error: 0.0528
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0361 - val_loss: 0.0027 - val_mean_absolute_error: 0.0409
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0348 - val_loss: 0.0039 - val_mean_absolute_error: 0.0521
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0365 - val_loss: 0.0024 - val_mean_absolute_error: 0.0382
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0346 - val_loss: 0.0018 - val_mean_absolute_error: 0.0301

# %%
modelCNNLSTM.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 1, 64)          │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,885 (151.90 KB)
#  Trainable params: 12,961 (50.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 25,924 (101.27 KB)

# %%
# Đánh giá mô hình trên tập kiểm tra
test_loss, test_mae = modelCNNLSTM.evaluate(X_test, y_test, verbose=0)

print(f"Độ lỗi trên tập kiểm tra: {test_loss}")
print(f"Độ chính xác trên tập kiểm tra: {test_mae}")

# Dự đoán giá trị trên tập kiểm tra
predictions = modelCNNLSTM.predict(X_test)

# Tính toán Mean Absolute Error
mae = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
# Out:
# Độ lỗi trên tập kiểm tra: 0.0008713346323929727
# Độ chính xác trên tập kiểm tra: 0.022662052884697914
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# Mean Absolute Error: 0.022662055393565795

# %%
import matplotlib.pyplot as plt

# Dự đoán giá trị trên tập huấn luyện và kiểm tra
modelCNNLSTM_pred = modelCNNLSTM.predict(X_train).flatten()
modelCNNLSTM_pred = modelCNNLSTM.predict(X_test).flatten()

plt.figure(figsize=(24,8))

# Vẽ giá trị thực tế
plt.plot(np.concatenate([y_train, y_test]), label='Giá thực tế', color='red')

# Vẽ kết quả dự đoán từ mô hình CNN trên tập huấn luyện
plt.plot(range(len(y_train)), cnn_train_pred, label='Giá dự đoán train', color='green')

# Vẽ kết quả dự đoán từ mô hình CNN trên tập kiểm tra
plt.plot(range(len(y_train), len(y_train) + len(y_test)), cnn_test_pred, label='Giá dự đoán test', color='blue')

plt.title('So sánh dự báo và thực tế sử dụng mô hình CNN + LSTM') # Đặt tên biểu đồ
plt.xlabel('Thời gian') # Đặt tên hàm x
plt.ylabel('Sản lượng điện') # Đặt tên hàm y
plt.legend() # Chú thích
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Huấn luyện mô hình, sử dụng tập validation
history = modelCNNLSTM.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# Lấy dữ liệu loss từ lịch sử huấn luyện
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Tạo một chuỗi epochs để vẽ trên trục x
epochs = range(len(training_loss))

# Vẽ biểu đồ
plt.figure(figsize=(12, 8))

plt.plot(epochs, training_loss, label='Training Loss', color='blue')
plt.plot(epochs, validation_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mean_absolute_error: 0.0299 - val_loss: 0.0017 - val_mean_absolute_error: 0.0287
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0309 - val_loss: 0.0018 - val_mean_absolute_error: 0.0293
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0291 - val_loss: 0.0018 - val_mean_absolute_error: 0.0302
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0275 - val_loss: 0.0015 - val_mean_absolute_error: 0.0270
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0277 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0276 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0278 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mean_absolute_error: 0.0268 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0253 - val_loss: 0.0014 - val_mean_absolute_error: 0.0255
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0275 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mean_absolute_error: 0.0232 - val_loss: 0.0011 - val_mean_absolute_error: 0.0219
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0224 - val_loss: 9.2573e-04 - val_mean_absolute_error: 0.0201
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0262 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0217 - val_loss: 9.8402e-04 - val_mean_absolute_error: 0.0200
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0215 - val_loss: 0.0010 - val_mean_absolute_error: 0.0228
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0202 - val_loss: 9.6993e-04 - val_mean_absolute_error: 0.0198
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0191 - val_loss: 8.6317e-04 - val_mean_absolute_error: 0.0185
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0192 - val_loss: 9.1770e-04 - val_mean_absolute_error: 0.0186
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mean_absolute_error: 0.0239 - val_loss: 8.6205e-04 - val_mean_absolute_error: 0.0190
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0201 - val_loss: 0.0010 - val_mean_absolute_error: 0.0227
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0183 - val_loss: 8.3311e-04 - val_mean_absolute_error: 0.0182
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0174 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0158 - val_loss: 9.7686e-04 - val_mean_absolute_error: 0.0225
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0182 - val_loss: 7.0128e-04 - val_mean_absolute_error: 0.0155
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0159 - val_loss: 6.4576e-04 - val_mean_absolute_error: 0.0152
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0186 - val_loss: 6.6601e-04 - val_mean_absolute_error: 0.0152
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0183 - val_loss: 6.5306e-04 - val_mean_absolute_error: 0.0149
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0144 - val_loss: 9.4675e-04 - val_mean_absolute_error: 0.0204
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0156 - val_loss: 7.3394e-04 - val_mean_absolute_error: 0.0165
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0179 - val_loss: 8.1509e-04 - val_mean_absolute_error: 0.0187
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0153 - val_loss: 6.3476e-04 - val_mean_absolute_error: 0.0146
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5003e-04 - mean_absolute_error: 0.0142 - val_loss: 6.3854e-04 - val_mean_absolute_error: 0.0148
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0150 - val_loss: 7.8636e-04 - val_mean_absolute_error: 0.0189
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0177 - val_loss: 9.4033e-04 - val_mean_absolute_error: 0.0225
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0166 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0168 - val_loss: 6.6977e-04 - val_mean_absolute_error: 0.0164
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0138 - val_loss: 7.3962e-04 - val_mean_absolute_error: 0.0180
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0140 - val_loss: 5.4079e-04 - val_mean_absolute_error: 0.0132
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0170 - val_loss: 6.6762e-04 - val_mean_absolute_error: 0.0151
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0171 - val_loss: 9.6835e-04 - val_mean_absolute_error: 0.0218
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0165 - val_loss: 8.7717e-04 - val_mean_absolute_error: 0.0171
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0148 - val_loss: 6.7086e-04 - val_mean_absolute_error: 0.0154
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1932e-04 - mean_absolute_error: 0.0142 - val_loss: 6.7757e-04 - val_mean_absolute_error: 0.0153
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4477e-04 - mean_absolute_error: 0.0135 - val_loss: 8.4933e-04 - val_mean_absolute_error: 0.0213
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0149 - val_loss: 7.3877e-04 - val_mean_absolute_error: 0.0160
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0148 - val_loss: 5.4624e-04 - val_mean_absolute_error: 0.0132
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5270e-04 - mean_absolute_error: 0.0140 - val_loss: 5.5526e-04 - val_mean_absolute_error: 0.0135
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6158e-04 - mean_absolute_error: 0.0138 - val_loss: 8.6820e-04 - val_mean_absolute_error: 0.0221
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0185 - val_loss: 7.5019e-04 - val_mean_absolute_error: 0.0169
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5890e-04 - mean_absolute_error: 0.0127 - val_loss: 4.5431e-04 - val_mean_absolute_error: 0.0122

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Tính toán các độ đo cho mỗi mô hình
models = [cnn_model, modelCNNLSTM]
model_names = ['CNN', 'CNN+LSTM']
metrics = []

for model in models:
    predictions = model.predict(X_test).flatten()
    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, predictions)
    metrics.append([mae, mse, rmse, r2])

# Tạo DataFrame để hiển thị kết quả
df_metrics = pd.DataFrame(metrics, columns=['MAE', 'MSE', 'RMSE', 'R2'], index=model_names)
print(df_metrics)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#                MAE       MSE      RMSE        R2
# CNN       0.038390  0.002413  0.049125  0.975334
# CNN+LSTM  0.022662  0.000871  0.029518  0.991094
